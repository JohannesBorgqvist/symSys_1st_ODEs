# %% [markdown]
# # Error search Hydons model ansatze degree 2
# *Date:* 2021-10-11,<br>
# *Written by:* Johannes Borgqvist.<br>
#
# This document contains an attempt of finding the error in the calculations of the symmetry generators for Hydon's model. The model at hand is the following two component ODE system:
#
# \begin{align}
# \dfrac{\mathrm{d}y_1}{\mathrm{d}t}&=\dfrac{ty_1+y_2^2}{y_1 y_2-t^2}=\omega_1(t,y_1,y_2),\\
# \dfrac{\mathrm{d}y_2}{\mathrm{d}t}&=\dfrac{ty_2+y_1^2}{y_1 y_2-t^2}=\omega_2(t,y_1,y_2).
# \end{align}
#
# Now, I was under the impression that everything was fine since the script currently returns the correct results in the cases of Hydon's model, the linear model and the DBH model for the cases where we use a first order ansatz. However, it turns out that when I just attempted to execute this script for an ansatze of degree 2 there is an error message. So I'll see what the problem is here.

# %% [markdown]
# # The entire output of the program after adding some printing of the algebraic equations
# Okay, so it was clear that there is an issue with solving the algebraic equations. So I added a printing message here and here follows the corresponding error message as well:
#
#
# ==========================================================================================================
# INITIATING CALCULATIONS WITH INPUT:
#         model           =       hydons_model,
#         tangent degree  =       2.
#
#
#                         Step 1 out of 6: Loading the model...
#                                 The model was successfully loaded!
#                                 Done!
#                         Step 2 out of 6: Creating tangent ansätze...
#                                 Done!
#                         Step 3 out of 6: Calculating the linearised symmetry conditions...
#                                 Done!
#                         Step 4 out of 6: Deriving the determining equations...
#                                 Done!
#                         Step 5 out of 6: Solving the determining equations...
# The number of algebraic equations is:   14<br>
#
#
# Eq 1 out of 14:$$- C_{1} - C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \left(C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\right) - x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# Traceback (most recent call last):
#   File "launch_symmetry_calculations.py", line 68, in <module>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 819, in solve_determining_equations
#     LHS_list,RHS_list = solve_algebraic_equation(eq_temp,const_remaining)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 412, in solve_algebraic_equation
#     RHS.append(sol_temp[0])
# IndexError: list index out of range

# %% [markdown]
# Okay, so we see by eye, that it should be possible to cancel a few terms here. So, what we'll do is to add the commands "expand(cancel())" to the command and see what comes of it.

# %% [markdown]
# ==========================================================================================================
# INITIATING CALCULATIONS WITH INPUT:
#         model           =       hydons_model,
#         tangent degree  =       2.
#
#
#                         Step 1 out of 6: Loading the model...
#                                 The model was successfully loaded!
#                                 Done!
#                         Step 2 out of 6: Creating tangent ansätze...
#                                 Done!
#                         Step 3 out of 6: Calculating the linearised symmetry conditions...
#                                 Done!
#                         Step 4 out of 6: Deriving the determining equations...
#                                 Done!
#                         Step 5 out of 6: Solving the determining equations...
# The number of algebraic equations is:   14<br>
#
#
# Eq 1 out of 14:$$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# <br>Solving: $- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$ for $\operatorname{c_{2 1}}{\left(s \right)}$<br>
# Traceback (most recent call last):
#   File "launch_symmetry_calculations.py", line 68, in <module>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 821, in solve_determining_equations
#     LHS_list,RHS_list = solve_algebraic_equation(eq_temp,const_remaining)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 414, in solve_algebraic_equation
#     RHS.append(sol_temp[0])
# IndexError: list index out of range

# %% [markdown]
# Now, we see what the problem is, hey? So this is in fact an amazing test case because the solve command does not find the arbitrary function when it is formulated as an integral! So we need to add some extra code here in order to see how this problem will be solved.
#
# Let's see what the coeff function returns then!

# %% [markdown]
# ==========================================================================================================
# INITIATING CALCULATIONS WITH INPUT:
#         model           =       hydons_model,
#         tangent degree  =       2.
#
#
#                         Step 1 out of 6: Loading the model...
#                                 The model was successfully loaded!
#                                 Done!
#                         Step 2 out of 6: Creating tangent ansätze...
#                                 Done!
#                         Step 3 out of 6: Calculating the linearised symmetry conditions...
#                                 Done!
#                         Step 4 out of 6: Deriving the determining equations...
#                                 Done!
#                         Step 5 out of 6: Solving the determining equations...
# The number of algebraic equations is:   14<br>
#
#
# Eq 1 out of 14:$$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# <br>Solving: $- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$ for $\operatorname{c_{2 1}}{\left(s \right)}$<br>
# <br>What does the ''expr.coeff'' return in this case?<br>$$\textrm{expr.coeff(arbitrary_function)}=0$$
# Traceback (most recent call last):
#   File "launch_symmetry_calculations.py", line 68, in <module>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 822, in solve_determining_equations
#     LHS_list,RHS_list = solve_algebraic_equation(eq_temp,const_remaining)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 415, in solve_algebraic_equation
#     RHS.append(sol_temp[0])
# IndexError: list index out of range

# %% [markdown]
# So this might actually be the solution to our problem. If
#
# $$\textrm{expr.coeff(arbitrary_function)=0}$$
#
# Then, we must have some type of integral term of the unknown function. All integral terms use the dummy variable "s" so perhaps it can be identified using the command "exp.coeff(arbitrary_function(s))".
#
# No, when I think about it this won't work. But perhaps the args command can tell us something?

# %% [markdown]
# ==========================================================================================================
# INITIATING CALCULATIONS WITH INPUT:
#         model           =       hydons_model,
#         tangent degree  =       2.
#
#
#                         Step 1 out of 6: Loading the model...
#                                 The model was successfully loaded!
#                                 Done!
#                         Step 2 out of 6: Creating tangent ansätze...
#                                 Done!
#                         Step 3 out of 6: Calculating the linearised symmetry conditions...
#                                 Done!
#                         Step 4 out of 6: Deriving the determining equations...
#                                 Done!
#                         Step 5 out of 6: Solving the determining equations...
# The number of algebraic equations is:   14<br>
#
#
# Eq 1 out of 14:$$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# <br>Solving: $- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$ for $\operatorname{c_{2 1}}{\left(s \right)}$<br>
# <br>What does the ''expr.coeff'' return in this case?<br>$$\textrm{expr.coeff(arbitrary_function)}=0$$
# <br>What does the ''expr.coeff'' return in this case?<br>$$\textrm{expr.coeff(arbitrary_function)}=0$$
# <br>What does the ''expr.args'' return in this case?
# \begin{align}
# - C_{1},\;\;\left\{\right\},\;\;0\\
# 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds,\;\;\left\{\operatorname{c_{2 1}}{\left(s \right)}\right\},\;\;1\\
# \end{align}
# The unknown function at first:
# $$4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds$$
# The factors in this term:
# $$\left( 4, \  \left[ \left( \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds, \  1\right)\right]\right)$$
# Traceback (most recent call last):
#   File "launch_symmetry_calculations.py", line 68, in <module>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 836, in solve_determining_equations
#     LHS_list,RHS_list = solve_algebraic_equation(eq_temp,const_remaining)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 429, in solve_algebraic_equation
#     RHS.append(sol_temp[0])
# IndexError: list index out of range
#
# IndexError: list index out of range

# %% [markdown]
# But wow, this is nice! This means that we can at least identify the integral here. Let's see if we can see if sympy can tell us which of the arguments that contain an unknown function. This should be accesible through atoms(UndefFunc) or what ever it is called.

# %% [markdown]
# What happens if we have another function as a factor btw?
# Let's see...

# %%
from sympy import *
t = Symbol('t')
s = Symbol('s')
C = Symbol('C')
f = symbols('f',cls=Function)
expr = 4*t*Integral(f(t),(s,0,t))
print(expr)
factors = factor_list(expr)
print(factors)
print(factors[0])
print(factors[1])
print(len(factors[1]))
unknown_term = factors[1][len(factors[1])-1][0]
print(unknown_term)
unknown_factor = simplify(expr/unknown_term)
print("Term to be solved for:\n$$%s$$"%(latex(unknown_term)))
print("Factor in front of this term:\n$$%s$$"%(latex(unknown_factor)))
#for factor in factor_list:
#    print(factor)
# Out:
# 4*t*Integral(f(t), (s, 0, t))
# (4, [(t, 1), (Integral(f(t), (s, 0, t)), 1)])
# 4
# [(t, 1), (Integral(f(t), (s, 0, t)), 1)]
# 2
# Integral(f(t), (s, 0, t))
# Term to be solved for:
# $$\int\limits_{0}^{t} f{\left(t \right)}\, ds$$
# Factor in front of this term:
# $$4 t$$

# %% [markdown]
# Term to be solved for:
# $$\int\limits_{0}^{t} f{\left(t \right)}\, ds$$
# Factor in front of this term:
# $$4 t$$
#
# Let's see if we can get this to work in practice then! Can we solve an equation involving this expression for this strange integral?

# %%
eq_temp = expr - (3*C*t**2)
print("Equation to solve:\n$$%s=0$$"%(latex(eq_temp)))
sol_temp = solve(eq_temp,unknown_term)
print("Solution:\n$$%s$$"%(latex(sol_temp[0])))
# Out:
# Equation to solve:
# $$- 3 C t^{2} + 4 t \int\limits_{0}^{t} f{\left(t \right)}\, ds=0$$
# Solution:
# $$\frac{3 C t}{4}$$

# %% [markdown]
# Equation to solve:
# $$- 3 C t^{2} + 4 t \int\limits_{0}^{t} f{\left(t \right)}\, ds=0$$
# Solution:
# $$\left[ \frac{3 C t}{4}\right]$$
# So this actually does work! Let's implement it and see what the program spits out!

# %% [markdown]
# ==========================================================================================================
# INITIATING CALCULATIONS WITH INPUT:
#         model           =       hydons_model,
#         tangent degree  =       2.
#
#
#                         Step 1 out of 6: Loading the model...
#                                 The model was successfully loaded!
#                                 Done!
#                         Step 2 out of 6: Creating tangent ansätze...
#                                 Done!
#                         Step 3 out of 6: Calculating the linearised symmetry conditions...
#                                 Done!
#                         Step 4 out of 6: Deriving the determining equations...
#                                 Done!
#                         Step 5 out of 6: Solving the determining equations...
# The number of algebraic equations is:   14<br>
#
#
# Eq 1 out of 14:$$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# The solutions:
# \begin{align*}
# \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}\\
# \end{align*}
# Traceback (most recent call last):
#   File "launch_symmetry_calculations.py", line 68, in <module>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 861, in solve_determining_equations
#     c_mat[sub_index] = c_mat[sub_index].subs(LHS_list[index],RHS_list[index])
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/matrices/immutable.py", line 85, in __setitem__
#     raise TypeError("Cannot set values of {}".format(self.__class__))
# TypeError: Cannot set values of <class 'sympy.matrices.immutable.ImmutableDenseMatrix'>
# famous-fred:Code%

# %% [markdown]
# So that is pretty nice at least, because now we have solved that equation! But it seems like there is an issue with the substitution steps afterwards. Be we are approaching though, are we not?

# %% [markdown]
# ==========================================================================================================
# INITIATING CALCULATIONS WITH INPUT:
#         model           =       hydons_model,
#         tangent degree  =       2.
#
#
#                         Step 1 out of 6: Loading the model...
#                                 The model was successfully loaded!
#                                 Done!
#                         Step 2 out of 6: Creating tangent ansätze...
#                                 Done!
#                         Step 3 out of 6: Calculating the linearised symmetry conditions...
#                                 Done!
#                         Step 4 out of 6: Deriving the determining equations...
#                                 Done!
#                         Step 5 out of 6: Solving the determining equations...
# The number of algebraic equations is:   14<br>
#
#
# Eq 1 out of 14:$$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# The solutions:
# \begin{align*}
# \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}\\
# \end{align*}
# Equation:
# $$C_{1} + C_{14} x_{0} + C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds - 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds$$
# LHS:
# $$\int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds$$
# RHS:
# $$\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}$$
# LHS_list[index].type:<br>$$\textrm{<class 'sympy.integrals.integrals.Integral'>}$$
#
# Traceback (most recent call last):
#   File "launch_symmetry_calculations.py", line 68, in <module>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 863, in solve_determining_equations
#     c_mat[sub_index] = c_mat[sub_index].subs(LHS_list[index],RHS_list[index])
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/matrices/immutable.py", line 85, in __setitem__
#     raise TypeError("Cannot set values of {}".format(self.__class__))
# TypeError: Cannot set values of <class 'sympy.matrices.immutable.ImmutableDenseMatrix'>

# %% [markdown]
# It seems like the next problem is with the subs command. Apparently we cannot use subs with an arbitrary unknown function. Let see if we can solve this right away here.

# %%
K = Symbol('K')
eq_temp = eq_temp + (K*t**3)
print("Temporary equation:\n$$%s=0$$"%(latex(eq_temp)))
eq_temp = eq_temp.subs(unknown_term,sol_temp[0])
print("Substituting $%s$ with $%s$"%(latex(unknown_term),latex(sol_temp[0])))
print("Equation afterwards:\n$$%s=0$$"%(latex(eq_temp)))
# Out:
# Temporary equation:
# $$- 3 C t^{2} + K t^{3} + 4 t \int\limits_{0}^{t} f{\left(t \right)}\, ds=0$$
# Substituting $\int\limits_{0}^{t} f{\left(t \right)}\, ds$ with $\frac{3 C t}{4}$
# Equation afterwards:
# $$K t^{3}=0$$

# %% [markdown]
# The output:<br>
# Temporary equation:
# $$- 3 C t^{2} + K t^{3} + 4 t \int\limits_{0}^{t} f{\left(t \right)}\, ds=0$$
# Substituting $\int\limits_{0}^{t} f{\left(t \right)}\, ds$ with $\frac{3 C t}{4}$
# Equation afterwards:
# $$K t^{3}=0$$
#
# OK, but this actually does what it is supposed to. So something else is the matter here...

# %% [markdown]
# I think I just realised what the issue is. Imagine that we have $s\,f(s)$ in the integrand instead of $f(s)$. I think this is where the error message comes from since we then have a Mul in the integrand. Let us see if this is the case.

# %%
#+ C*t - K*exp(t)
expr = 4*t*Integral(f(s)*s,(s,0,t)) 
factors = factor_list(expr)
print("Factors:\n$$%s$$"%(latex(factors)))
unknown_term = factors[1][len(factors[1])-1][0]
unknown_factor = simplify(expr/unknown_term)
eq_temp = expr + C*t - K*exp(t)
sol_temp = solve(eq_temp,unknown_term)
print("Expression:\n$$%s$$"%(eq_temp))
print("Unknown factor:\n$$%s$$"%(unknown_factor))
print("Unknown term:\n$$%s$$"%(unknown_term))
print("Solving $%s=0$ for $%s$ yields $%s$"%(latex(eq_temp),latex(unknown_term),latex(sol_temp[0])))
# Out:
# Factors:
# $$\left( 4, \  \left[ \left( t, \  1\right), \  \left( \int\limits_{0}^{t} s f{\left(s \right)}\, ds, \  1\right)\right]\right)$$
# Expression:
# $$C*t - K*exp(t) + 4*t*Integral(s*f(s), (s, 0, t))$$
# Unknown factor:
# $$4*t$$
# Unknown term:
# $$Integral(s*f(s), (s, 0, t))$$
# Solving $C t - K e^{t} + 4 t \int\limits_{0}^{t} s f{\left(s \right)}\, ds=0$ for $\int\limits_{0}^{t} s f{\left(s \right)}\, ds$ yields $\frac{- C t + K e^{t}}{4 t}$

# %% [markdown]
# Factors:
# $$\left( 4, \  \left[ \left( t, \  1\right), \  \left( \int\limits_{0}^{t} s f{\left(s \right)}\, ds, \  1\right)\right]\right)$$
# Expression:
# $$C*t - K*exp(t) + 4*t*Integral(s*f(s), (s, 0, t))$$
# Unknown factor:
# $$4*t$$
# Unknown term:
# $$Integral(s*f(s), (s, 0, t))$$
# Solving $C t - K e^{t} + 4 t \int\limits_{0}^{t} s f{\left(s \right)}\, ds=0$ for $\int\limits_{0}^{t} s f{\left(s \right)}\, ds$ yields $\frac{- C t + K e^{t}}{4 t}$
#
# Next, we try to substitute this into another equation!

# %%
new_eq = 4*t*Integral(f(s)*s,(s,0,t)) - K*t**2 + C*t
print("Equation before:\n$$%s$$"%(latex(new_eq)))
new_eq = new_eq.subs(unknown_term,sol_temp[0])
print("Equation after:\n$$%s$$"%(latex(new_eq)))
# Out:
# Equation before:
# $$C t - K t^{2} + 4 t \int\limits_{0}^{t} s f{\left(s \right)}\, ds$$
# Equation after:
# $$- K t^{2} + K e^{t}$$

# %% [markdown]
# Equation before:
# $$C t - K t^{2} + 4 t \int\limits_{0}^{t} s f{\left(s \right)}\, ds$$
# Equation after:
# $$- K t^{2} + K e^{t}$$

# %% [markdown]
# It turned out that there was some error with Immutable matrices versus matrices. Anyhow after casting the matrices to the Matrix format the output was the following:
#
# Eq 1 out of 14:$$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# The solutions:
# \begin{align*}
# \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}\\
# \end{align*}
# Eq 2 out of 14:$$- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}=0$$
# The solutions:
# \begin{align*}
# C_{2}=\frac{C_{16} \left(1 - 9 e^{4}\right)}{8}\\
# \end{align*}
# Eq 3 out of 14:$$C_{17} - C_{3}=0$$
# The solutions:
# \begin{align*}
# C_{3}=C_{17}\\
# \end{align*}
# Eq 4 out of 14:$$- 3 C_{17} x_{0} - C_{4}=0$$
# The solutions:
# \begin{align*}
# C_{17}=0\\
# C_{4}=0\\
# \end{align*}
# Eq 5 out of 14:$$C_{18} - C_{5}=0$$
# The solutions:
# \begin{align*}
# C_{5}=C_{18}\\
# \end{align*}
# Eq 6 out of 14:$$- \frac{- C_{16} e^{4} + 2 C_{6} x_{0}}{2 x_{0}}=0$$
# The solutions:
# \begin{align*}
# 0=0\\
# C_{6}=\frac{C_{16} e^{4}}{2 x_{0}}\\
# \end{align*}
# Eq 7 out of 14:$$- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}=0$$
# The solutions:
# \begin{align*}
# C_{16}=0\\
# C_{7}=\frac{C_{16} x_{0}}{2}\\
# \end{align*}
# Eq 8 out of 14:$$- C_{8}=0$$
# The solutions:
# \begin{align*}
# C_{8}=0\\
# \end{align*}
# Eq 9 out of 14:$$C_{18} - C_{9}=0$$
# The solutions:
# \begin{align*}
# C_{9}=C_{18}\\
# \end{align*}
# Eq 10 out of 14:$$- C_{10} + C_{14}=0$$
# The solutions:
# \begin{align*}
# C_{10}=C_{14}\\
# \end{align*}
# Eq 11 out of 14:$$- C_{11}=0$$
# The solutions:
# \begin{align*}
# C_{11}=0\\
# \end{align*}
# Eq 12 out of 14:$$- C_{12}=0$$
# The solutions:
# \begin{align*}
# C_{12}=0\\
# \end{align*}
# Eq 13 out of 14:$$- C_{13}=0$$
# The solutions:
# \begin{align*}
# C_{13}=0\\
# \end{align*}
# Eq 14 out of 14:$$- C_{15}=0$$
# The solutions:
# \begin{align*}
# C_{15}=0\\
# \end{align*}

# %% [markdown]
# OK, last fixes, some other error with the substitutions into the tangents. So let's print this and see what the issue is.

# %% [markdown]
# \begin{align*}
# \eta_{0}&=x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{0 5}}{\left(x_{0} \right)} + \operatorname{c_{0 0}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 0}}{\left(x_{0} \right)}\;\textrm{substituted with}\;C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{0 5}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 5}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 4}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 3}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 2}}{\left(x_{0} \right)}\;\textrm{substituted with}\;\operatorname{c_{2 1}}{\left(x_{0} \right)}\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 1}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 0}}{\left(x_{0} \right)}\;\textrm{substituted with}\;\frac{C_{16} x_{0}}{2}\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 5}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 4}}{\left(x_{0} \right)}\;\textrm{substituted with}\;\operatorname{c_{2 1}}{\left(x_{0} \right)}\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 3}}{\left(x_{0} \right)}\;\textrm{substituted with}\;C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\
# \end{align*}

# %% [markdown]
# # Print out the algebraic substitution steps
# ## Iter 1 out of 15
# Eq 1 out of 14:$$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=0$$
# The solutions:
# \begin{align*}
# \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds=\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{1} + C_{14} x_{0} + C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds - 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{16} \left(- \frac{1}{8} + \frac{e^{4}}{8}\right) + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\C_{16} \left(- \frac{x_{0}}{2} + \frac{x_{0} e^{4}}{2}\right) + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16
# } e^{4}\\C_{17}\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{C_{16}}{8} + \frac{C_{16} e^{4}}{8} + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4} - C_{16} \left(- \frac{1}{8} + \frac{e^{4}}{8}\right) - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4}}{2 x_{0}} - C_{6}\\- 2 C_{16} x_{0} e^{4} - C_{16} \left(- \frac{x_{0}}{2} + \frac{x_{0} e^{4}}{2}\right) - C_{7}\\- 6 C_{17} x_{0} - C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11} + \frac{C_{16} e^{4}}{2 x_{0}}\\- C_{12} - C_{17}\\- C_{13} - 8 C_{17} x_{0}^{2}\\- C_{15} - \frac{C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- 6 C_{17} x_{0} - C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12} - C_{17}\\- C_{13} - 8 C_{17} x_{0}^{2}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# ## Iter 2 out of 15
# Eq 2 out of 14:$$- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}=0$$
# The solutions:
# \begin{align*}
# C_{2}=\frac{C_{16} \left(1 - 9 e^{4}\right)}{8}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{C_{16}}{8} + \frac{C_{16} e^{4}}{8} + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- 6 C_{17} x_{0} - C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12} - C_{17}\\- C_{13} - 8 C_{17} x_{0}^{2}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- 6 C_{17} x_{0} - C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12} - C_{17}\\- C_{13} - 8 C_{17} x_{0}^{2}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# ## Iter 3 out of 15
# Eq 3 out of 14:$$C_{17} - C_{3}=0$$
# The solutions:
# \begin{align*}
# C_{3}=C_{17}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{17}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- 6 C_{17} x_{0} - C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12} - C_{17}\\- C_{13} - 8 C_{17} x_{0}^{2}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- 6 C_{17} x_{0} - C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12} - C_{17}\\- C_{13} - 8 C_{17} x_{0}^{2}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# ## Iter 4 out of 15
# Eq 4 out of 14:$$- 3 C_{17} x_{0} - C_{4}=0$$
# The solutions:
# \begin{align*}
# C_{17}=0\\
# C_{4}=0\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{17}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- 6 C_{17} x_{0} - C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12} - C_{17}\\- C_{13} - 8 C_{17} x_{0}^{2}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12}\\- C_{13}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# ## Iter 5 out of 15
# Eq 5 out of 14:$$C_{18} - C_{5}=0$$
# The solutions:
# \begin{align*}
# C_{5}=C_{18}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12}\\- C_{13}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12}\\- C_{13}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# ## Iter 6 out of 15
# Eq 6 out of 14:$$\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}=0$$
# The solutions:
# \begin{align*}
# 0=0\\
# C_{6}=\frac{C_{16} e^{4}}{2 x_{0}}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\\frac{C_{16} e^{4}}{2 x_{0}}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12}\\- C_{13}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12}\\- C_{13}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# ## Iter 7 out of 15
# Eq 7 out of 14:$$- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}=0$$
# The solutions:
# \begin{align*}
# C_{16}=0\\
# C_{7}=- \frac{5 C_{16} x_{0} e^{4}}{2}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\\frac{C_{16} e^{4}}{2 x_{0}}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\- \frac{5 C_{16} x_{0} e^{4}}{2}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\\frac{- 2 C_{11} x_{0} + C_{16} e^{4}}{2 x_{0}}\\- C_{12}\\- C_{13}\\\frac{- 2 C_{15} x_{0} - C_{16} e^{4}}{2 x_{0}}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# ## Iter 8 out of 15
# Eq 8 out of 14:$$- C_{8}=0$$
# The solutions:
# \begin{align*}
# C_{8}=0\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\- \frac{5 C_{16} x_{0} e^{4}}{2}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\- \frac{5 C_{16} x_{0} e^{4}}{2}\\0\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# ## Iter 9 out of 15
# Eq 9 out of 14:$$C_{18} - C_{9}=0$$
# The solutions:
# \begin{align*}
# C_{9}=C_{18}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\- \frac{5 C_{16} x_{0} e^{4}}{2}\\0\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\- \frac{5 C_{16} x_{0} e^{4}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# ## Iter 10 out of 15
# Eq 10 out of 14:$$- C_{10} + C_{14}=0$$
# The solutions:
# \begin{align*}
# C_{10}=C_{14}\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\- \frac{5 C_{16} x_{0} e^{4}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\- \frac{5 C_{16} x_{0} e^{4}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
#
#
# ## Iter 11 out of 15
# Eq 11 out of 14:$$- C_{11}=0$$
# The solutions:
# \begin{align*}
# C_{11}=0\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\\\0\\\operatorname{c_{21}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{
# 17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\
# \- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{
# 17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\
# \- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# ## Iter 12 out of 15
# Eq 12 out of 14:$$- C_{12}=0$$
# The solutions:
# \begin{align*}
# C_{12}=0\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x
# _{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\
# , ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{
# 17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
#
# ## Iter 13 out of 15
# Eq 13 out of 14:$$- C_{13}=0$$
# The solutions:
# \begin{align*}
# C_{13}=0\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x
# _{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x
# _{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{1
# 5}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{
# 17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{
# 17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
#
# ## Iter 14 out of 15
# Eq 14 out of 14:$$- C_{15}=0$$
# The solutions:
# \begin{align*}
# C_{15}=0\\
# \end{align*}
# Solutions before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{21}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solutions after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\\frac{C_{16} x_{0}}{2}\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x
# _{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0
# \\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{
# 17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}\\C_{
# 17} - C_{3}\\- 3 C_{17} x_{0} - C_{4}\\C_{18} - C_{5}\\\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}\\- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}\\- C_{8}\\C_{18} - C_{9}\\- C_{10} + C_{14}\\- C_{11}\\- C_{12}\\- C_{13}\\- C_{15}\end{matrix}\right]$$

# %% [markdown]
# \begin{align*}
# \eta_{0}&=x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{0 5}}{\left(x_{0} \right)} + \operatorname{c_{0 0}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 0}}{\left(x_{0} \right)}\;\textrm{substituted with}\;C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{0 5}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 5}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 4}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 3}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 2}}{\left(x_{0} \right)}\;\textrm{substituted with}\;\operatorname{c_{2 1}}{\left(x_{0} \right)}\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{0 1}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 0}}{\left(x_{0} \right)}\;\textrm{substituted with}\;\frac{C_{16} x_{0}}{2}\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 5}}{\left(x_{0} \right)}\;\textrm{substituted with}\;0\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 4}}{\left(x_{0} \right)}\;\textrm{substituted with}\;\operatorname{c_{2 1}}{\left(x_{0} \right)}\\
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)},\;\;\operatorname{c_{1 3}}{\left(x_{0} \right)}\;\textrm{substituted with}\;C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\
# \end{align*}

# %% [markdown]
# The script crashes at the last substitution withthe following error message:
#
# Traceback (most recent call last):
#   File "launch_symmetry_calculations.py", line 68, in <module>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 913, in solve_determining_equations
#     eta_list[tangent_number] = eta_list[tangent_number].subs(c[index](x[0]),c_mat[index])
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 952, in subs
#     rv = rv._subs(old, new, **kwargs)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1066, in _subs
#     rv = fallback(self, old, new)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1038, in fallback
#     arg = arg._subs(old, new, **hints)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1066, in _subs
#     rv = fallback(self, old, new)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1038, in fallback
#     arg = arg._subs(old, new, **hints)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1064, in _subs
#     rv = self._eval_subs(old, new)
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/concrete/expr_with_limits.py", line 364, in _eval_subs
#     raise ValueError(
# ValueError: substitution can not create dummy dependencies

# %%
# Ok, so create an integral expression like the one we see
C14, C18, t, s = symbols('C14 C18 t s')
f, g = symbols('f g', cls=Function)
expr = C14 - C18*t - t*f(t) + Integral(f(s),(s,0,t))
expr_2 = t**3
print(expr)
expr_2.subs(g(t),expr)
# Out:
# C14 - C18*t - t*f(t) + Integral(f(s), (s, 0, t))
# t**3

# %% [markdown]
# # Temporary fix
# For some reason this last substitution did not work. So I told sympy only to conduct the substitution if the coefficient at hand actually exist in the left hand side. Now the script did the following:

# %% [markdown]
# # Hold on a bit
#
# Now when I looked through the solution of the algebraic equations, I realised that these were wrong again. So let's go through these steps again one by one. I realise that we are tired of this but it has to be done!

# %% [markdown]
# # Looking through the algebraic solutions again
# Equation:
# $$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds$$
# Solutions:
# \begin{align*}
# \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds&=\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}\\
# \end{align*}
# Equation:
# $$- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{2}&=\frac{C_{16} \left(1 - 9 e^{4}\right)}{8}\\
# \end{align*}
# Equation:
# $$C_{17} - C_{3}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{3}&=C_{17}\\
# \end{align*}
# Equation:
# $$- 3 C_{17} x_{0} - C_{4}$$
# Basis functions:
# $$\left[ - 3 x_{0}, \  1\right]$$
# Solutions:
# \begin{align*}
# C_{17}&=0\\
# C_{4}&=0\\
# \end{align*}
# Equation:
# $$C_{18} - C_{5}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{5}&=C_{18}\\
# \end{align*}
# Equation:
# $$\frac{C_{16} e^{4} - 2 C_{6} x_{0}}{2 x_{0}}$$
# Basis functions:
# $$\left[ 1, \  x_{0}\right]$$
# Solutions:
# \begin{align*}
# 0&=0\\
# C_{6}&=\frac{C_{16} e^{4}}{2 x_{0}}\\
# \end{align*}
# Equation:
# $$- \frac{5 C_{16} x_{0} e^{4}}{2} + \frac{C_{16} x_{0}}{2} - C_{7}$$
# Basis functions:
# $$\left[ \frac{x_{0}}{2}, \  1\right]$$
# Solutions:
# \begin{align*}
# C_{16}&=0\\
# C_{7}&=- \frac{5 C_{16} x_{0} e^{4}}{2}\\
# \end{align*}
# Equation:
# $$- C_{8}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{8}&=0\\
# \end{align*}
# Equation:
# $$C_{18} - C_{9}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{9}&=C_{18}\\
# \end{align*}
# Equation:
# $$- C_{10} + C_{14}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{10}&=C_{14}\\
# \end{align*}
# Equation:
# $$- C_{11}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{11}&=0\\
# \end{align*}
# Equation:
# $$- C_{12}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{12}&=0\\
# \end{align*}
# Equation:
# $$- C_{13}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{13}&=0\\
# \end{align*}
# Equation:
# $$- C_{15}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{15}&=0\\
# \end{align*}

# %% [markdown]
# # Now we've localised the error!
# Ok, it seems like the actual solving of the algebraic equations goes wrong. So we need some polishing on this step. The first attempt will be just to write everything, i.e. the expression at hand, with a common denominator using "simplify" and then use "fraction" in order to extract the nominator. In this case we will manage to solve the problem when certain expressions are written as fraction with a polynomial in the denominator. Let's see what this yields.

# %% [markdown]
# ### Output from the script after the modification
# Equation:
# $$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds$$
# Solutions:
# \begin{align*}
# \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds&=\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}\\
# \end{align*}
# Equation:
# $$- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{2}&=\frac{C_{16} \left(1 - 9 e^{4}\right)}{8}\\
# \end{align*}
# Equation:
# $$C_{17} - C_{3}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{3}&=C_{17}\\
# \end{align*}
# Equation:
# $$- 3 C_{17} x_{0} - C_{4}$$
# Basis functions:
# $$\left[ - 3 x_{0}, \  1\right]$$
# Solutions:
# \begin{align*}
# C_{17}&=0\\
# C_{4}&=0\\
# \end{align*}
# Equation:
# $$C_{18} - C_{5}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{5}&=C_{18}\\
# \end{align*}
# Equation:
# $$- \frac{- C_{16} e^{4} + 2 C_{6} x_{0}}{2 x_{0}}$$
# Basis functions:
# $$\left[ \frac{e^{4}}{2 x_{0}}, \  1\right]$$
# Solutions:
# \begin{align*}
# C_{16}&=0\\
# C_{6}&=0\\
# \end{align*}
# Equation:
# $$- C_{7}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{7}&=0\\
# \end{align*}
# Equation:
# $$- C_{8}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{8}&=0\\
# \end{align*}
# Equation:
# $$C_{18} - C_{9}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{9}&=C_{18}\\
# \end{align*}
# Equation:
# $$- C_{10} + C_{14}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{10}&=C_{14}\\
# \end{align*}
# Equation:
# $$- C_{11}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{11}&=0\\
# \end{align*}
# Equation:
# $$- C_{12}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{12}&=0\\
# \end{align*}
# Equation:
# $$- C_{13}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{13}&=0\\
# \end{align*}
# Equation:
# $$- C_{15}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{15}&=0\\
# \end{align*}

# %% [markdown]
# So the above bit actually seem to be right... But why isn't the correct answer returned? Let's look through the solutions together with the substitutions again...

# %% [markdown]
# # Checking each of the algebraic equations
# ## Iter 1 out of 14
# Equation:
# $$- C_{1} - 2 C_{18} x_{0}^{2} + 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds$$
# Solutions:
# \begin{align*}
# \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds&=\frac{C_{1}}{4} + \frac{C_{18} x_{0}^{2}}{2}\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{1} + C_{14} x_{0} + C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds - 4 \int\limits_{0}^{x_{0}} s \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{16} \left(- \frac{1}{8} + \frac{e^{4}}{8}\right) + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\C_{16} \left(- \frac{x_{0}}{2} + \frac{x_{0} e^{4}}{2}\right) + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{C_{16}}{8} + \frac{C_{16} e^{4}}{8} + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left
# (s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{C_{16}}{8} + \frac{C_{16} e^{4}}{8} + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname
# {c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{C_{16}}{8} + \frac{C_{16} e^{4}}{8} + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname
# {c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# ## Iter 2 out of 14
# Equation:
# $$- \frac{9 C_{16} e^{4}}{8} + \frac{C_{16}}{8} - C_{2}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{2}&=\frac{C_{16} \left(1 - 9 e^{4}\right)}{8}\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- \frac{C_{16}}{8} + \frac{C_{16} e^{4}}{8} + C_{2}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left
# (s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4
# }\\C_{17}\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{1
# 5}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{1
# 5}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# ## Iter 3 out of 14
# Equation:
# $$C_{17} - C_{3}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{3}&=C_{17}\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{3}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4
# }\\C_{17}\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{17}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{
# 4}\\C_{17}\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{17}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{
# 15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{17}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{
# 15}\\C_{16} e^{4}\\C_{17}\end{matrix}\right]$$
# ## Iter 4 out of 14
# Equation:
# $$- 3 C_{17} x_{0} - C_{4}$$
# Basis functions:
# $$\left[ - 3 x_{0}, \  1\right]$$
# Solutions:
# \begin{align*}
# C_{17}&=0\\
# C_{4}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\C_{17}\\C_{17} x_{0} + C_{4}\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\8 C_{17} x_{0} + C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13} + 4 C_{17} x_{0}^{2}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{
# 4}\\C_{17}\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# ## Iter 5 out of 14
# Equation:
# $$C_{18} - C_{5}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{5}&=C_{18}\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\- C_{18} + C_{5} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# ## Iter 6 out of 14
# Equation:
# $$- \frac{- C_{16} e^{4} + 2 C_{6} x_{0}}{2 x_{0}}$$
# Basis functions:
# $$\left[ \frac{e^{4}}{2 x_{0}}, \  1\right]$$
# Solutions:
# \begin{align*}
# C_{16}&=0\\
# C_{6}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\- C_{16} e^{4}\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{6}\\- \frac{C_{16} x_{0}}{2} + \frac{C_{16} x_{0} e^{4}}{2} + C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\C_{16} e^{4}\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# ## Iter 7 out of 14
# Equation:
# $$- C_{7}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{7}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\C_{7}\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# ## Iter 8 out of 14
# Equation:
# $$- C_{8}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{8}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\C_{8}\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# ## Iter 9 out of 14
# Equation:
# $$C_{18} - C_{9}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{9}&=C_{18}\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\- C_{18} + C_{9} + \operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
#
# ## Iter 10 out of 14
# Equation:
# $$- C_{10} + C_{14}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{10}&=C_{14}\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{10} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# ## Iter 11 out of 14
# Equation:
# $$- C_{11}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{11}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{11}\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# ## Iter 12 out of 14
# Equation:
# $$- C_{12}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{12}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\C_{12}\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# ## Iter 13 out of 14
# Equation:
# $$- C_{13}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{13}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\C_{13}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# ## Iter 14 out of 14
# Equation:
# $$- C_{15}$$
# Basis functions:
# $$\left[ 1\right]$$
# Solutions:
# \begin{align*}
# C_{15}&=0\\
# \end{align*}
# Solution before:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\C_{15}\\0\\0\end{matrix}\right]$$
# Solution after:
# $$\mathbf{c}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\end{matrix}\right]$$
# Algebraic before:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\end{matrix}\right]$$
# Algebraic after:
# $$\mathbf{c}_{\textrm{alg}}=\left[\begin{matrix}C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\0\\0\\0\\\operatorname{c_{2 1}}{\left(x_{0} \right)}\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\\C_{14} - C_{18} x_{0} + x_{0} \operatorname{c_{2 1}}{\left(x_{0} \right)} + \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\0\\0\\0\end{matrix}\right]$$

# %% [markdown]
# # Checking all subsequent steps
# Okay, so by now the actual calculations actually seem right. So let's check the subsequent steps after these calculations.
#
# ## The tangents after substitution
# The constants in the final solution:
# $$\left[\begin{matrix}C_{18}\\C_{14}\end{matrix}\right]$$
# The overall tangents
# \begin{align*}
# \eta_{0}&=C_{14} x_{0} - C_{18} x_{0}^{2} - x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)}\\
# \eta_{1}&=C_{14} x_{1} - C_{18} x_{0} x_{1} + x_{0} x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{1} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{2}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)}\\
# \eta_{2}&=C_{14} x_{2} - C_{18} x_{0} x_{2} + x_{0} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{1}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\\
# \end{align*}
# ## The components of the overall tangents
# Tangent 0 out of 3
# The tangent:
# $$\left[\begin{matrix}- x_{0}^{2}\\- x_{0} x_{1}\\- x_{0} x_{2}\end{matrix}\right]$$
# The linearised symmetry conditions:
# $$\left[ 2 x_{0}^{2} x_{1} + x_{0} x_{2}^{2} - x_{1}^{2} x_{2}, \  2 x_{0}^{2} x_{2} + x_{0} x_{1}^{2} - x_{1} x_{2}^{2}\right]$$
# Tangent 1 out of 3
# The tangent:
# $$\left[\begin{matrix}x_{0}\\x_{1}\\x_{2}\end{matrix}\right]$$
# The linearised symmetry conditions:
# $$\left[ 0, \  0\right]$$
# Tangent 2 out of 3
# The tangent:
# $$\left[\begin{matrix}- x_{0}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{0} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{1} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)}\\x_{0} x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{1} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds + x_{2}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)}\\x_{0} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{1}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)}\, ds\end{matrix}\right]$$
# The linearised symmetry conditions:
# $$\left[ - 2 x_{0}^{2} x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} - x_{0} x_{2}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{1}^{2} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)}, \  - 2 x_{0}^{2} x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} - x_{0} x_{1}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{1} x_{2}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)}\right]$$
