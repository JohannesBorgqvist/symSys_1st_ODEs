# %% [markdown]
# # DBH ansätze degree 2
#
# Ok, so apparently there are new problems with the DBH model using ansätze of degree 2. The model at hand is the following:
#
# \begin{align*}
# \dv{w_{1}}{t}&=- w_{1} w_{2} - w_{1} w_{3} + w_{2} w_{3},\\
# \dv{w_{2}}{t}&=- w_{1} w_{2} + w_{1} w_{3} - w_{2} w_{3},\\
# \dv{w_{3}}{t}&=w_{1} w_{2} - w_{1} w_{3} - w_{2} w_{3}.\\
# \end{align*}
#
# For some reason, the script stopped finding the correct generators or it lost one of them. So let's print the algebraic steps and see if we can trace down the error.

# %% [markdown]
# # Solving the algebraic equations!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [26/271]
# ## Equation 1 out of 23
# Solving equation:
# $$- C_{3}=0$$
# Solutions
# \begin{align*}
# C_{3}&=0\\
# \end{align*}
# ## Equation 2 out of 23
# Solving equation:
# $$- C_{2} x_{0} - C_{4} x_{0} - C_{5} + C_{7} x_{0}=0$$
# Solutions
# \begin{align*}
# C_{2}&=- C_{4} + C_{7}\\
# C_{5}&=0\\
# \end{align*}
# ## Equation 3 out of 23
# Solving equation:
# $$- C_{6}=0$$
# Solutions
# \begin{align*}
# C_{6}&=0\\
# \end{align*}
# ## Equation 4 out of 23
# Solving equation:
# $$2 C_{4} x_{0} - 2 C_{7} x_{0} - C_{8}=0$$
# Solutions
# \begin{align*}
# C_{4}&=C_{7}\\
# C_{8}&=0\\
# \end{align*}
# ## Equation 5 out of 23
# Solving equation:
# $$- 2 C_{7} x_{0} - C_{9}=0$$
# Solutions
# \begin{align*}
# C_{7}&=0\\
# C_{9}&=0\\
# \end{align*}
# ## Equation 6 out of 23
# Solving equation:
# $$- C_{10}=0$$
# Solutions
# \begin{align*}
# C_{10}&=0\\
# \end{align*}
# ## Equation 7 out of 23
# Solving equation:
# $$- C_{11} x_{0}^{2} + C_{12} x_{0} - C_{13} + C_{21} x_{0}^{2} - C_{22} x_{0}=0$$
# Solutions
# \begin{align*}
# C_{11}&=C_{21}\\
# C_{12}&=C_{22}\\
# C_{13}&=0\\
# \end{align*}
# ## Equation 8 out of 23
# Solving equation:
# $$- C_{15} + 2 C_{17} x_{0} + C_{21} x_{0}^{2} - C_{31} x_{0}^{2} - 2 C_{32} x_{0} + C_{40}=0$$
# Solutions
# \begin{align*}
# C_{17}&=C_{32}\\
# C_{21}&=C_{31}\\
# C_{15}&=C_{40}\\
# \end{align*}
# ## Equation 9 out of 23
# Solving equation:
# $$C_{14} x_{0} - C_{16} - C_{34} x_{0}=0$$
# Solutions
# \begin{align*}
# C_{14}&=C_{34}\\
# C_{16}&=0\\
# \end{align*}
# ## Equation 10 out of 23
# Solving equation:
# $$- C_{18} - C_{24} x_{0} - C_{27} x_{0} + C_{32} x_{0} + C_{34} x_{0} - C_{40}=0$$
# Solutions
# \begin{align*}
# C_{24}&=- C_{27} + C_{32} + C_{34}\\
# C_{18}&=- C_{40}\\
# \end{align*}
# ## Equation 11 out of 23
# Solving equation:
# $$- C_{19} + C_{22} x_{0} - C_{37} x_{0} - C_{40}=0$$
# Solutions
# \begin{align*}
# C_{22}&=C_{37}\\
# C_{19}&=- C_{40}\\
# \end{align*}
# ## Equation 12 out of 23
# Solving equation:
# $$- C_{20} + C_{27} x_{0} + C_{37} x_{0}=0$$
# Solutions
# \begin{align*}
# C_{27}&=- C_{37}\\
# C_{20}&=0\\
# \end{align*}
# ## Equation 13 out of 23
# Solving equation:
# $$- C_{23}=0$$
# Solutions
# \begin{align*}
# C_{23}&=0\\
# \end{align*}
# ## Equation 14 out of 23
# Solving equation:
# $$- C_{25} - 2 C_{34} x_{0} - 2 C_{37} x_{0} - C_{40}=0$$
# Solutions
# \begin{align*}
# C_{34}&=- C_{37}\\
# C_{25}&=- C_{40}\\
# \end{align*}
# ## Equation 15 out of 23
# Solving equation:
# $$- C_{26} - 2 C_{37} x_{0}=0$$
# Solutions
# \begin{align*}
# C_{37}&=0\\
# C_{26}&=0\\
# \end{align*}
# ## Equation 16 out of 23
# Solving equation:
# $$- C_{28} + C_{40}=0$$
# Solutions
# \begin{align*}
# C_{28}&=C_{40}\\
# \end{align*}
# ## Equation 17 out of 23
# Solving equation:
# $$- C_{29} - C_{40}=0$$
# Solutions
# \begin{align*}
# C_{29}&=- C_{40}\\
# \end{align*}
# ## Equation 18 out of 23
# Solving equation:
# $$- C_{30}=0$$
# Solutions
# \begin{align*}
# C_{30}&=0\\
# \end{align*}
# ## Equation 19 out of 23
# Solving equation:
# $$- C_{33}=0$$
# Solutions
# \begin{align*}
# C_{33}&=0\\
# \end{align*}
# ## Equation 20 out of 23
# Solving equation:
# $$- C_{35} - C_{40}=0$$
# Solutions
# \begin{align*}
# C_{35}&=- C_{40}\\
# \end{align*}
# ## Equation 21 out of 23
# Solving equation:
# $$- C_{36}=0$$
# Solutions
# \begin{align*}
# C_{36}&=0\\
# \end{align*}
# ## Equation 22 out of 23
# Solving equation:
# $$- C_{38} - C_{40}=0$$
# Solutions
# \begin{align*}
# C_{38}&=- C_{40}\\
# \end{align*}
# ## Equation 23 out of 23
# Solving equation:
# $$- C_{39}=0$$
# Solutions
# \begin{align*}
# C_{39}&=0\\
# \end{align*}

# %% [markdown]
# # Attempt 2
# Solving equation:
# $$- C_{3}=0$$
# Solving equation:
# $$- C_{2} x_{0} - C_{4} x_{0} - C_{5} + C_{7} x_{0}=0$$
# Solving equation:
# $$- C_{6}=0$$
# Solving equation:
# $$2 C_{4} x_{0} - 2 C_{7} x_{0} - C_{8}=0$$
# Solving equation:
# $$- 2 C_{7} x_{0} - C_{9}=0$$
# Solving equation:
# $$- C_{10}=0$$
# Solving equation:
# $$- C_{11} x_{0}^{2} + C_{12} x_{0} - C_{13} + C_{21} x_{0}^{2} - C_{22} x_{0}=0$$
# Solving equation:
# $$- C_{15} + 2 C_{17} x_{0} + C_{21} x_{0}^{2} - C_{31} x_{0}^{2} - 2 C_{32} x_{0} + C_{40}=0$$
# Solving equation:
# $$C_{14} x_{0} - C_{16} - C_{21} x_{0}^{2} - C_{34} x_{0}=0$$
# Solving equation:
# $$- C_{18} - C_{24} x_{0} - C_{27} x_{0} + C_{32} x_{0} + C_{34} x_{0} - C_{40}=0$$
# Solving equation:
# $$- C_{19} + C_{22} x_{0} - C_{37} x_{0} - C_{40}=0$$
# Solving equation:
# $$- C_{20} + C_{27} x_{0} + C_{37} x_{0}=0$$
# Solving equation:
# $$- C_{23}=0$$
# Solving equation:
# $$- C_{25} - 2 C_{34} x_{0} - 2 C_{37} x_{0} - C_{40}=0$$
# Solving equation:
# $$- C_{26} - 2 C_{37} x_{0}=0$$
# Solving equation:
# $$- C_{28} + C_{40}=0$$
# Solving equation:
# $$- C_{29} - C_{40}=0$$
# Solving equation:
# $$- C_{30}=0$$
# Solving equation:
# $$- C_{33}=0$$
# Solving equation:
# $$- C_{35} - C_{40}=0$$
# Solving equation:
# $$- C_{36}=0$$
# Solving equation:
# $$- C_{38} - C_{40}=0$$
# Solving equation:
# $$- C_{39}=0$$

# %% [markdown]
# # The component tangents and their linearised symmetry conditions
# ## Tangent 0
# Tangent 0:
# $$\left[ 1, \  0, \  0, \  0\right]$$
# Lin. sym:
# $$\left[ 0, \  0, \  0\right]$$
# ## Tangent 1
# Tangent 1:
# $$\left[ 0, \  - \frac{x_{3}}{x_{0}}, \  0, \  0\right]$$
# Lin. sym:
# $$\left[ x_{0} x_{1} x_{2} - x_{0} x_{1} x_{3} + x_{0} x_{3}^{2} - x_{3}, \  x_{2} x_{3} - x_{3}^{2}, \  - x_{2} x_{3} + x_{3}^{2}\right]$$
# ## Tangent 2
# Tangent 2:
# $$\left[ x_{0}^{2}, \  - 2 x_{0} x_{1} + 1, \  - 2 x_{0} x_{2} + 1, \  - 2 x_{0} x_{3} + 1\right]$$
# Lin. sym:
# $$\left[ 0, \  0, \  0\right]$$
# ## Tangent 3
# Tangent 3:
# $$\left[ - \frac{x_{2}}{2 x_{0}} + \frac{x_{3}}{2 x_{0}}, \  0, \  0, \  0\right]$$
# Lin. sym:
# $$\left[ - 2 x_{0} x_{1}^{2} x_{2}^{2} + 2 x_{0} x_{1}^{2} x_{3}^{2} + 2 x_{0} x_{1} x_{2}^{2} x_{3} - 2 x_{0} x_{1} x_{2} x_{3}^{2} - x_{1} x_{2}^{2} + x_{1} x_{3}^{2} + x_{2}^{2} x_{3} - x_{2} x_{3}^{2}, \  - 2 x_{0} x_{1}^{2} x_{2}^{2} + 4 x_{0} x_{1}^{2} x_{2} x_{3} - 2 x_{0} x_{1}^{2} x_{3}^{2} - 2 x_{0} x_{1} x_{2}^{2} x_{3} + 2 x_{0} x_{1} x_{2} x_{3}^{2} - x_{1} x_{2}^{2} + 2 x_{1} x_{2} x_{3} - x_{1} x_{3}^{2} - x_{2}^{2} x_{3} + x_{2} x_{3}^{2}, \  2 x_{0} x_{1}^{2} x_{2}^{2} - 4 x_{0} x_{1}^{2} x_{2} x_{3} + 2 x_{0} x_{1}^{2} x_{3}^{2} - 2 x_{0} x_{1} x_{2}^{2} x_{3} + 2 x_{0} x_{1} x_{2} x_{3}^{2} + x_{1} x_{2}^{2} - 2 x_{1} x_{2} x_{3} + x_{1} x_{3}^{2} - x_{2}^{2} x_{3} + x_{2} x_{3}^{2}\right]$$
# ## Tangent 4
# Tangent 4:
# $$\left[ -1, \  - \frac{x_{3}}{x_{0}}, \  0, \  0\right]$$
# Lin. sym:
# $$\left[ x_{0} x_{1} x_{2} - x_{0} x_{1} x_{3} + x_{0} x_{3}^{2} - x_{3}, \  x_{2} x_{3} - x_{3}^{2}, \  - x_{2} x_{3} + x_{3}^{2}\right]$$
# ## Tangent 5
# Tangent 5:
# $$\left[ 0, \  - \frac{x_{2}}{x_{0}} - \frac{x_{3}}{x_{0}}, \  0, \  0\right]$$
# Lin. sym:
# $$\left[ x_{0} x_{2}^{2} + x_{0} x_{3}^{2} - x_{2} - x_{3}, \  x_{2}^{2} - x_{3}^{2}, \  - x_{2}^{2} + x_{3}^{2}\right]$$
# ## Tangent 6
# Tangent 6:
# $$\left[ \operatorname{c_{3 2}}{\left(x_{0} \right)}, \  - x_{1} x_{2} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{1} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)} + x_{2} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)}, \  - x_{1} x_{2} \operatorname{c_{3 2}}{\left(x_{0} \right)} + x_{1} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{2} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)}, \  x_{1} x_{2} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{1} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{2} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)}\right]$$
# Lin. sym:
# $$\left[ 0, \  0, \  0\right]$$
#
#                 For some reason this part of the code was invoked which has to do with finding non-symmetries! Here are the indices and the generators
#                         Failed generator 0 out of 4
# 5
# [1, 0, 0, 0]
# [x_0*x_1*x_2 - x_0*x_1*x_3 + x_0*x_3**2 - x_3, x_2*x_3 - x_3**2, -x_2*x_3 + x_3**2]
#                         Failed generator 1 out of 4
# 4
# [0, -x_3/x_0, 0, 0]
# [-2*x_0*x_1**2*x_2**2 + 2*x_0*x_1**2*x_3**2 + 2*x_0*x_1*x_2**2*x_3 - 2*x_0*x_1*x_2*x_3**2 - x_1*x_2**2 + x_1*x_3**2 + x_2**2*x_3 - x_2*x_3**2, -2*x_0*x_1**2*x_2**2 + 4*x_0*x_1**2*x_2*x_3 - 2*x_0*x_1**2*x_3**2 - 2*x_0*x_1*x_2**2*x_3 + 2*x_0*x_1*x_2*x_3**2 - x_1*x_2**2 + 2*x_1*x_2*x_3 - x_1*x_3**2 - x_2**2*x_3 + x_2*x_3**2, 2*x_0*x_1**2*x_2**2 - 4*x_0*x_1**2*x_2*x_3 + 2*x_0*x_1**2*x_3**2 - 2*x_0*x_1*x_2**2*x_3 + 2*x_0*x_1*x_2*x_3**2 + x_1*x_2**2 - 2*x_1*x_2*x_3 + x_1*x_3**2 - x_2**2*x_3 + x_2*x_3**2]
#                         Failed generator 2 out of 4
# 3
# [x_0**2, -2*x_0*x_1 + 1, -2*x_0*x_2 + 1, -2*x_0*x_3 + 1]
# [x_0*x_1*x_2 - x_0*x_1*x_3 + x_0*x_3**2 - x_3, x_2*x_3 - x_3**2, -x_2*x_3 + x_3**2]
#                         Failed generator 3 out of 4
# 1
# [-x_2/(2*x_0) + x_3/(2*x_0), 0, 0, 0]
# [x_0*x_2**2 + x_0*x_3**2 - x_2 - x_3, x_2**2 - x_3**2, -x_2**2 + x_3**2]

# %% [markdown]
# # Attempt 2
# # The component tangents and their linearised symmetry conditions
# ## Tangent 0
# Tangent 0:
# $$\left[ -1, \  0, \  0, \  0\right]$$
# Lin. sym:
# $$\left[ 0, \  0, \  0\right]$$
# ## Tangent 1
# Tangent 1:
# $$\left[ - x_{0}, \  x_{1}, \  x_{2}, \  x_{3}\right]$$
# Lin. sym:
# $$\left[ 0, \  0, \  0\right]$$
# ## Tangent 2
# Tangent 2:
# $$\left[ 1, \  0, \  0, \  0\right]$$
# Lin. sym:
# $$\left[ 0, \  0, \  0\right]$$
# ## Tangent 3
# Tangent 3:
# $$\left[ \operatorname{c_{3 2}}{\left(x_{0} \right)}, \  - x_{1} x_{2} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{1} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)} + x_{2} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)}, \  - x_{1} x_{2} \operatorname{c_{3 2}}{\left(x_{0} \right)} + x_{1} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{2} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)}, \  x_{1} x_{2} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{1} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)} - x_{2} x_{3} \operatorname{c_{3 2}}{\left(x_{0} \right)}\right]$$
# Lin. sym:
