# %% [markdown]
# # Linear model degree 2
# It seems like every time we solve one problem, another problem seems to arise. So this time there is an issue with the substitutions into the tangents at the very end of the script. So let's see if we can solve this.
#
# This is the initial error message:
#
#
# famous-fred:Code% python launch_symmetry_calculations.py linear_model 2<br>
# INITIATING CALCULATIONS WITH INPUT:<br>
#         model           =       linear_model,<br>
#         tangent degree  =       2.<br>
#
#
#                         Step 1 out of 6: Loading the model...<br>
#                                 The model was successfully loaded!<br>
#                                 Done!<br>
#                         Step 2 out of 6: Creating tangent ansätze...<br>
#                                 Done!<br>
#                         Step 3 out of 6: Calculating the linearised symmetry conditions...<br>
#                                 Done!<br>
#                         Step 4 out of 6: Deriving the determining equations...<br>
#                                 Done!<br>
#                         Step 5 out of 6: Solving the determining equations...<br>
# Traceback (most recent call last):<br>
#   File "launch_symmetry_calculations.py", line 68, in <module><br>
#     conduct_symmetry_calculations.calculate_symmetries_ODEs(file_name,tangent_degree)<br>
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/conduct_symmetry_calculations.py", line 158, in calculate_symmetries_ODEs<br>
#     X = symmetry_toolbox_first_order_ODEs.solve_determining_equations(<br>
#   File "/scratch/borgqvist/Dropbox/Work/Projects/symSys_1st_ODEs/Code/symmetry_toolbox_first_order_ODEs.py", line 915, in solve_determining_equations<br>
#     eta_list[tangent_number] = eta_list[tangent_number].subs(c[index](x[0]),c_mat[index])       <br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 952, in subs
#     rv = rv._subs(old, new, **kwargs)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1066, in _subs
#     rv = fallback(self, old, new)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1038, in fallback
#     arg = arg._subs(old, new, **hints)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1066, in _subs
#     rv = fallback(self, old, new)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1038, in fallback
#     arg = arg._subs(old, new, **hints)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1064, in _subs
#     rv = self._eval_subs(old, new)<br>
#   File "/home/borgqvist/anaconda3/lib/python3.8/site-packages/sympy/concrete/expr_with_limits.py", line 364, in _eval_subs<br>
#     raise ValueError(<br>
# ValueError: substitution can not create dummy dependencies<br>
#
#
# So let's print things around the substitution step and see what happens! That is around line 915 in solve_determining_equations.

# %% [markdown]
# # Looping through the tangents and performing the substitutions:
# ## Tangent 1 out of 3
# $$\eta_{0}=x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{0 5}}{\left(x_{0} \right)} + \operatorname{c_{0 0}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ with:
# $$C_{1} + C_{10} \left(- \frac{e^{2 x_{0}}}{4} + \frac{e^{- 2 x_{0}}}{4}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{4} - \frac{e^{- 2 x_{0}}}{4}\right) - \frac{C_{18} e^{2 x_{0}}}{4} - \frac{C_{18}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{4} + C_{8} \left(\frac{e^{2 x_{0}}}{4} - \frac{1}{2} + \frac{e^{- 2 x_{0}}}{4}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 5}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{3 e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(\frac{3 e^{2 x_{0}}}{8} + \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{5}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(3 C_{16} e^{6 x_{0}} - 3 C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} - 3 C_{17} e^{6 x_{0}} + 5 C_{17} e^{4 x_{0}} - C_{17} e^{2 x_{0}} - C_{17} + 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$
# Substituting $\operatorname{c_{0 4}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{5} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{6} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right)$$
# Substituting $\operatorname{c_{0 3}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(- \frac{e^{2 x_{0}}}{8} - \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(- \frac{e^{2 x_{0}}}{8} + \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(- \frac{e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(- C_{16} e^{6 x_{0}} + C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} + C_{17} e^{6 x_{0}} - 3 C_{17} e^{4 x_{0}} - 5 C_{17} e^{2 x_{0}} - C_{17} + 8 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{4 x_{0}} - 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds + 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$

# %% [markdown]
# # Ok, so we decide to build our own function
# This doesn't just cut it man! Let's build our own function!

# %%
# The functions substitutes the an unknown coefficient in the provided tangent
# with the provided output function. For some reason the standard subs function
# breaks down with very complicated integral expressions and it gives an error
# message saying "ValueError: substitution can not create dummy dependencies".
# So to circiumvent this we build our own function which conducts the substitution
# at hand
def substitute_tangents(old_tangent,original_function,target_function):
    # Allocate the new tangent which we will return
    new_tangent = old_tangent
    # Extract the coefficient
    coeff_temp = new_tangent.coeff(original_function)    
    # Check if the coefficient exist in the tangent
    if coeff_temp!=0:
        # Extract the coefficient
        coeff_temp = new_tangent.coeff(original_function)
        # Substract the original function and add the target!
        new_tangent += -(original_function*coeff_temp) + target_function*coeff_temp             
        # Expand and cancel things
        new_tangent =  cancel(expand(new_tangent))
    # Return the tangent at last
    return new_tangent

# %% [markdown]
# This was the output!
#
# # Looping through the tangents and performing the substitutions:
# ## Tangent 1 out of 3
# $$\eta_{0}=x_{1}^{2} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{0 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{0 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{0 5}}{\left(x_{0} \right)} + \operatorname{c_{0 0}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ with:
# $$C_{1} + C_{10} \left(- \frac{e^{2 x_{0}}}{4} + \frac{e^{- 2 x_{0}}}{4}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{4} - \frac{e^{- 2 x_{0}}}{4}\right) - \frac{C_{18} e^{2 x_{0}}}{4} - \frac{C_{18}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{4} + C_{8} \left(\frac{e^{2 x_{0}}}{4} - \frac{1}{2} + \frac{e^{- 2 x_{0}}}{4}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 5}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{3 e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(\frac{3 e^{2 x_{0}}}{8} + \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{5}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(3 C_{16} e^{6 x_{0}} - 3 C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} - 3 C_{17} e^{6 x_{0}} + 5 C_{17} e^{4 x_{0}} - C_{17} e^{2 x_{0}} - C_{17} + 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$
# Substituting $\operatorname{c_{0 4}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{5} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{6} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right)$$
# Substituting $\operatorname{c_{0 3}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(- \frac{e^{2 x_{0}}}{8} - \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(- \frac{e^{2 x_{0}}}{8} + \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(- \frac{e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(- C_{16} e^{6 x_{0}} + C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} + C_{17} e^{6 x_{0}} - 3 C_{17} e^{4 x_{0}} - 5 C_{17} e^{2 x_{0}} - C_{17} + 8 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{4 x_{0}} - 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds + 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$
# Substituting $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{5} \left(\frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{6} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right)$$
# Substituting $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{5} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{6} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right)$$
# Substituting $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ with:
# $$C_{13} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + C_{7} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right)$$
# Substituting $\operatorname{c_{1 5}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(- \frac{e^{2 x_{0}}}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{2} - \frac{e^{- 2 x_{0}}}{2}\right) - \frac{C_{18} e^{2 x_{0}}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{2} + C_{8} \left(\frac{e^{2 x_{0}}}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 4}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{e^{2 x_{0}}}{2} + \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{12} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{15} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} - \frac{e^{- 4 x_{0}}}{4}\right) + C_{9} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + \frac{\left(2 C_{16} e^{6 x_{0}} - C_{16} e^{4 x_{0}} - C_{16} - 2 C_{17} e^{6 x_{0}} + C_{17} e^{4 x_{0}} + 2 C_{17} e^{2 x_{0}} - C_{17} + 8 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 8 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds\right) e^{- 4 x_{0}}}{4}$$
# Substituting $\operatorname{c_{1 3}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{14} \left(\frac{1}{2} - \frac{e^{- 2 x_{0}}}{2}\right) - \frac{C_{18}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{2} + C_{8} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{12} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{15} \left(\frac{1}{2} - \frac{e^{- 4 x_{0}}}{2}\right) - \frac{C_{16}}{2} - \frac{C_{16} e^{- 4 x_{0}}}{2} + \frac{C_{17}}{2} - \frac{C_{17} e^{- 4 x_{0}}}{2} + C_{9} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + \operatorname{c_{2 2}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{12} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{15} \left(- \frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} - \frac{e^{- 4 x_{0}}}{4}\right) + \frac{C_{16}}{4} - \frac{C_{16} e^{- 4 x_{0}}}{4} - \frac{C_{17}}{4} - \frac{C_{17} e^{- 2 x_{0}}}{2} - \frac{C_{17} e^{- 4 x_{0}}}{4} + C_{9} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + \operatorname{c_{2 1}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ with:
# $$C_{13} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) + C_{7} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right)$$
# Substituting $\operatorname{c_{2 5}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(\frac{1}{2} - \frac{e^{2 x_{0}}}{2}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) - \frac{C_{18} e^{2 x_{0}}}{2} - \frac{C_{18}}{2} + C_{8} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{2 4}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{1}{2} - \frac{e^{2 x_{0}}}{2}\right) + C_{12} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + C_{15} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) + \frac{C_{16} e^{2 x_{0}}}{2} - \frac{C_{16}}{2} - \frac{C_{17} e^{2 x_{0}}}{2} + \frac{C_{17}}{2} + C_{9} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + 2 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 2 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds$$
# ## Tangent 2 out of 3
# $$\eta_{1}=x_{1}^{2} \operatorname{c_{1 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{1 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{1 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{1 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{1 5}}{\left(x_{0} \right)} + \operatorname{c_{1 0}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ with:
# $$C_{1} + C_{10} \left(- \frac{e^{2 x_{0}}}{4} + \frac{e^{- 2 x_{0}}}{4}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{4} - \frac{e^{- 2 x_{0}}}{4}\right) - \frac{C_{18} e^{2 x_{0}}}{4} - \frac{C_{18}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{4} + C_{8} \left(\frac{e^{2 x_{0}}}{4} - \frac{1}{2} + \frac{e^{- 2 x_{0}}}{4}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 5}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{3 e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(\frac{3 e^{2 x_{0}}}{8} + \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{5}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(3 C_{16} e^{6 x_{0}} - 3 C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} - 3 C_{17} e^{6 x_{0}} + 5 C_{17} e^{4 x_{0}} - C_{17} e^{2 x_{0}} - C_{17} + 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$
# Substituting $\operatorname{c_{0 4}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{5} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{6} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right)$$
# Substituting $\operatorname{c_{0 3}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(- \frac{e^{2 x_{0}}}{8} - \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(- \frac{e^{2 x_{0}}}{8} + \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(- \frac{e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(- C_{16} e^{6 x_{0}} + C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} + C_{17} e^{6 x_{0}} - 3 C_{17} e^{4 x_{0}} - 5 C_{17} e^{2 x_{0}} - C_{17} + 8 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{4 x_{0}} - 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds + 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$
# Substituting $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{5} \left(\frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{6} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right)$$
# Substituting $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{5} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{6} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right)$$
# Substituting $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ with:
# $$C_{13} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + C_{7} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right)$$
# Substituting $\operatorname{c_{1 5}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(- \frac{e^{2 x_{0}}}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{2} - \frac{e^{- 2 x_{0}}}{2}\right) - \frac{C_{18} e^{2 x_{0}}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{2} + C_{8} \left(\frac{e^{2 x_{0}}}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 4}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{e^{2 x_{0}}}{2} + \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{12} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{15} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} - \frac{e^{- 4 x_{0}}}{4}\right) + C_{9} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + \frac{\left(2 C_{16} e^{6 x_{0}} - C_{16} e^{4 x_{0}} - C_{16} - 2 C_{17} e^{6 x_{0}} + C_{17} e^{4 x_{0}} + 2 C_{17} e^{2 x_{0}} - C_{17} + 8 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 8 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds\right) e^{- 4 x_{0}}}{4}$$
# Substituting $\operatorname{c_{1 3}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{14} \left(\frac{1}{2} - \frac{e^{- 2 x_{0}}}{2}\right) - \frac{C_{18}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{2} + C_{8} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{12} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{15} \left(\frac{1}{2} - \frac{e^{- 4 x_{0}}}{2}\right) - \frac{C_{16}}{2} - \frac{C_{16} e^{- 4 x_{0}}}{2} + \frac{C_{17}}{2} - \frac{C_{17} e^{- 4 x_{0}}}{2} + C_{9} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + \operatorname{c_{2 2}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{12} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{15} \left(- \frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} - \frac{e^{- 4 x_{0}}}{4}\right) + \frac{C_{16}}{4} - \frac{C_{16} e^{- 4 x_{0}}}{4} - \frac{C_{17}}{4} - \frac{C_{17} e^{- 2 x_{0}}}{2} - \frac{C_{17} e^{- 4 x_{0}}}{4} + C_{9} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + \operatorname{c_{2 1}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ with:
# $$C_{13} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) + C_{7} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right)$$
# Substituting $\operatorname{c_{2 5}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(\frac{1}{2} - \frac{e^{2 x_{0}}}{2}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) - \frac{C_{18} e^{2 x_{0}}}{2} - \frac{C_{18}}{2} + C_{8} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{2 4}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{1}{2} - \frac{e^{2 x_{0}}}{2}\right) + C_{12} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + C_{15} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) + \frac{C_{16} e^{2 x_{0}}}{2} - \frac{C_{16}}{2} - \frac{C_{17} e^{2 x_{0}}}{2} + \frac{C_{17}}{2} + C_{9} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + 2 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 2 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds$$
# ## Tangent 3 out of 3
# $$\eta_{2}=x_{1}^{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{1} x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + x_{1} \operatorname{c_{2 3}}{\left(x_{0} \right)} + x_{2}^{2} \operatorname{c_{2 4}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 5}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ with:
# $$C_{1} + C_{10} \left(- \frac{e^{2 x_{0}}}{4} + \frac{e^{- 2 x_{0}}}{4}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{4} - \frac{e^{- 2 x_{0}}}{4}\right) - \frac{C_{18} e^{2 x_{0}}}{4} - \frac{C_{18}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{4} + C_{8} \left(\frac{e^{2 x_{0}}}{4} - \frac{1}{2} + \frac{e^{- 2 x_{0}}}{4}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{0 5}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{3 e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(\frac{3 e^{2 x_{0}}}{8} + \frac{1}{8} - \frac{3 e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(\frac{3 e^{2 x_{0}}}{8} - \frac{5}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(3 C_{16} e^{6 x_{0}} - 3 C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} - 3 C_{17} e^{6 x_{0}} + 5 C_{17} e^{4 x_{0}} - C_{17} e^{2 x_{0}} - C_{17} + 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 12 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$
# Substituting $\operatorname{c_{0 4}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{5} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{6} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right)$$
# Substituting $\operatorname{c_{0 3}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{e^{2 x_{0}}}{8} - \frac{1}{8} - \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{12} \left(- \frac{e^{2 x_{0}}}{8} - \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + C_{15} \left(- \frac{e^{2 x_{0}}}{8} + \frac{1}{8} + \frac{e^{- 2 x_{0}}}{8} - \frac{e^{- 4 x_{0}}}{8}\right) + C_{2} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{4} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{9} \left(- \frac{e^{2 x_{0}}}{8} + \frac{3}{8} - \frac{3 e^{- 2 x_{0}}}{8} + \frac{e^{- 4 x_{0}}}{8}\right) + \frac{\left(- C_{16} e^{6 x_{0}} + C_{16} e^{4 x_{0}} + C_{16} e^{2 x_{0}} - C_{16} + C_{17} e^{6 x_{0}} - 3 C_{17} e^{4 x_{0}} - 5 C_{17} e^{2 x_{0}} - C_{17} + 8 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{4 x_{0}} - 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds + 4 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds - 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{2 s}\, ds + 4 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{2 s}\, ds\right) e^{- 4 x_{0}}}{8}$$
# Substituting $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{5} \left(\frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{6} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right)$$
# Substituting $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ with:
# $$C_{3} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{5} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{6} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right)$$
# Substituting $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ with:
# $$C_{13} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + C_{7} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right)$$
# Substituting $\operatorname{c_{1 5}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(- \frac{e^{2 x_{0}}}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{2} - \frac{e^{- 2 x_{0}}}{2}\right) - \frac{C_{18} e^{2 x_{0}}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{2} + C_{8} \left(\frac{e^{2 x_{0}}}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 4}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{e^{2 x_{0}}}{2} + \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{12} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{15} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} - \frac{e^{- 4 x_{0}}}{4}\right) + C_{9} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + \frac{\left(2 C_{16} e^{6 x_{0}} - C_{16} e^{4 x_{0}} - C_{16} - 2 C_{17} e^{6 x_{0}} + C_{17} e^{4 x_{0}} + 2 C_{17} e^{2 x_{0}} - C_{17} + 8 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 8 e^{6 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds\right) e^{- 4 x_{0}}}{4}$$
# Substituting $\operatorname{c_{1 3}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(\frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + C_{14} \left(\frac{1}{2} - \frac{e^{- 2 x_{0}}}{2}\right) - \frac{C_{18}}{2} - \frac{C_{18} e^{- 2 x_{0}}}{2} + C_{8} \left(- \frac{1}{2} + \frac{e^{- 2 x_{0}}}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{12} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + C_{15} \left(\frac{1}{2} - \frac{e^{- 4 x_{0}}}{2}\right) - \frac{C_{16}}{2} - \frac{C_{16} e^{- 4 x_{0}}}{2} + \frac{C_{17}}{2} - \frac{C_{17} e^{- 4 x_{0}}}{2} + C_{9} \left(- \frac{1}{2} + \frac{e^{- 4 x_{0}}}{2}\right) + \operatorname{c_{2 2}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(- \frac{1}{4} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{12} \left(\frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + C_{15} \left(- \frac{1}{4} + \frac{e^{- 2 x_{0}}}{2} - \frac{e^{- 4 x_{0}}}{4}\right) + \frac{C_{16}}{4} - \frac{C_{16} e^{- 4 x_{0}}}{4} - \frac{C_{17}}{4} - \frac{C_{17} e^{- 2 x_{0}}}{2} - \frac{C_{17} e^{- 4 x_{0}}}{4} + C_{9} \left(\frac{1}{4} - \frac{e^{- 2 x_{0}}}{2} + \frac{e^{- 4 x_{0}}}{4}\right) + \operatorname{c_{2 1}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ with:
# $$C_{13} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) + C_{7} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right)$$
# Substituting $\operatorname{c_{2 5}}{\left(x_{0} \right)}$ with:
# $$C_{10} \left(\frac{1}{2} - \frac{e^{2 x_{0}}}{2}\right) + C_{14} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) - \frac{C_{18} e^{2 x_{0}}}{2} - \frac{C_{18}}{2} + C_{8} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + \operatorname{c_{2 3}}{\left(x_{0} \right)}$$
# Substituting $\operatorname{c_{2 4}}{\left(x_{0} \right)}$ with:
# $$C_{11} \left(\frac{1}{2} - \frac{e^{2 x_{0}}}{2}\right) + C_{12} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + C_{15} \left(\frac{e^{2 x_{0}}}{2} + \frac{1}{2}\right) + \frac{C_{16} e^{2 x_{0}}}{2} - \frac{C_{16}}{2} - \frac{C_{17} e^{2 x_{0}}}{2} + \frac{C_{17}}{2} + C_{9} \left(\frac{e^{2 x_{0}}}{2} - \frac{1}{2}\right) + 2 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 1}}{\left(s \right)} e^{- 2 s}\, ds - 2 e^{2 x_{0}} \int\limits_{0}^{x_{0}} \operatorname{c_{2 2}}{\left(s \right)} e^{- 2 s}\, ds$$

# %% [markdown]
# So this might work, let's run it all on our examples!

# %% [markdown]
# # Some new issue with the tangents
# Our home-made version do not seem to work. So let's see what's going on here by printing everything one more time!
#
# Original tangent:$$\eta=x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} + \operatorname{c_{0 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ is $1$<br>
# Replace $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ with $$\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Original tangent:$$\eta=\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Coefficient of $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ with $$\frac{\left(C_{2} e^{2 x_{0}} + C_{2} - C_{3} e^{2 x_{0}} + C_{3}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Coefficient of $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ with $$\frac{\left(- C_{2} e^{2 x_{0}} + C_{2} + C_{3} e^{2 x_{0}} + C_{3}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Coefficient of $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ with $$\frac{C_{4} e^{2 x_{0}}}{2} + \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} - \frac{C_{7}}{2}$$
# Original tangent:$$\eta=\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Coefficient of $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ with $$\frac{\left(C_{5} e^{4 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - C_{9} + 2 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Coefficient of $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ with $$\frac{\left(- C_{5} e^{2 x_{0}} + C_{5} + C_{6} e^{2 x_{0}} + C_{6} + C_{8} e^{2 x_{0}} - C_{8} - C_{9} e^{2 x_{0}} - C_{9} + 2 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Coefficient of $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ with $$\frac{C_{4} e^{2 x_{0}}}{2} - \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} + \frac{C_{7}}{2}$$
# Original tangent:$$\eta=\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 x_{1} \operatorname{c_{0 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 x_{2} \operatorname{c_{0 2}}{\left(x_{0} \right)} e^{2 x_{0}} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Coefficient of $\operatorname{c_{2 2}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{2 2}}{\left(x_{0} \right)}$ with $$\frac{C_{5} e^{2 x_{0}}}{2} - \frac{C_{5}}{2} - \frac{C_{6} e^{2 x_{0}}}{2} + \frac{C_{6}}{2} + \frac{C_{8} e^{2 x_{0}}}{2} + \frac{C_{8}}{2} - \frac{C_{9} e^{2 x_{0}}}{2} - \frac{C_{9}}{2} + \operatorname{c_{2 1}}{\left(x_{0} \right)}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{1 2}}{\left(x_{0} \right)} + \operatorname{c_{1 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ with $$\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{1 2}}{\left(x_{0} \right)} + \operatorname{c_{1 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ with $$\frac{\left(C_{2} e^{2 x_{0}} + C_{2} - C_{3} e^{2 x_{0}} + C_{3}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{1 2}}{\left(x_{0} \right)} + \operatorname{c_{1 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ with $$\frac{\left(- C_{2} e^{2 x_{0}} + C_{2} + C_{3} e^{2 x_{0}} + C_{3}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{1 2}}{\left(x_{0} \right)} + \operatorname{c_{1 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ is $1$<br>
# Replace $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ with $$\frac{C_{4} e^{2 x_{0}}}{2} + \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} - \frac{C_{7}}{2}$$
# Original tangent:$$\eta=\frac{C_{4} e^{2 x_{0}}}{2} + \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} - \frac{C_{7}}{2} + x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{1 2}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ is $x_2$<br>
# Replace $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ with $$\frac{\left(C_{5} e^{4 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - C_{9} + 2 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=\frac{\left(C_{4} e^{4 x_{0}} + C_{4} e^{2 x_{0}} + C_{5} x_{2} e^{4 x_{0}} + C_{5} x_{2} - C_{6} x_{2} e^{4 x_{0}} + C_{6} x_{2} + C_{7} e^{4 x_{0}} - C_{7} e^{2 x_{0}} + C_{8} x_{2} e^{4 x_{0}} - C_{8} x_{2} - C_{9} x_{2} e^{4 x_{0}} - C_{9} x_{2} + 2 x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 2 x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Coefficient of $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ with $$\frac{\left(- C_{5} e^{2 x_{0}} + C_{5} + C_{6} e^{2 x_{0}} + C_{6} + C_{8} e^{2 x_{0}} - C_{8} - C_{9} e^{2 x_{0}} - C_{9} + 2 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=\frac{\left(C_{4} e^{4 x_{0}} + C_{4} e^{2 x_{0}} + C_{5} x_{2} e^{4 x_{0}} + C_{5} x_{2} - C_{6} x_{2} e^{4 x_{0}} + C_{6} x_{2} + C_{7} e^{4 x_{0}} - C_{7} e^{2 x_{0}} + C_{8} x_{2} e^{4 x_{0}} - C_{8} x_{2} - C_{9} x_{2} e^{4 x_{0}} - C_{9} x_{2} + 2 x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 2 x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Coefficient of $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ with $$\frac{C_{4} e^{2 x_{0}}}{2} - \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} + \frac{C_{7}}{2}$$
# Original tangent:$$\eta=\frac{\left(C_{4} e^{4 x_{0}} + C_{4} e^{2 x_{0}} + C_{5} x_{2} e^{4 x_{0}} + C_{5} x_{2} - C_{6} x_{2} e^{4 x_{0}} + C_{6} x_{2} + C_{7} e^{4 x_{0}} - C_{7} e^{2 x_{0}} + C_{8} x_{2} e^{4 x_{0}} - C_{8} x_{2} - C_{9} x_{2} e^{4 x_{0}} - C_{9} x_{2} + 2 x_{1} \operatorname{c_{1 1}}{\left(x_{0} \right)} e^{2 x_{0}} + 2 x_{2} \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Coefficient of $\operatorname{c_{2 2}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{2 2}}{\left(x_{0} \right)}$ with $$\frac{C_{5} e^{2 x_{0}}}{2} - \frac{C_{5}}{2} - \frac{C_{6} e^{2 x_{0}}}{2} + \frac{C_{6}}{2} + \frac{C_{8} e^{2 x_{0}}}{2} + \frac{C_{8}}{2} - \frac{C_{9} e^{2 x_{0}}}{2} - \frac{C_{9}}{2} + \operatorname{c_{2 1}}{\left(x_{0} \right)}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 0}}{\left(x_{0} \right)}$ with $$\frac{\left(4 C_{1} e^{2 x_{0}} + C_{5} e^{4 x_{0}} - 2 C_{5} e^{2 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - 2 C_{9} e^{2 x_{0}} - C_{9} + 4 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{4}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 2}}{\left(x_{0} \right)}$ with $$\frac{\left(C_{2} e^{2 x_{0}} + C_{2} - C_{3} e^{2 x_{0}} + C_{3}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{0 1}}{\left(x_{0} \right)}$ with $$\frac{\left(- C_{2} e^{2 x_{0}} + C_{2} + C_{3} e^{2 x_{0}} + C_{3}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{1 0}}{\left(x_{0} \right)}$ with $$\frac{C_{4} e^{2 x_{0}}}{2} + \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} - \frac{C_{7}}{2}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{1 2}}{\left(x_{0} \right)}$ with $$\frac{\left(C_{5} e^{4 x_{0}} + C_{5} - C_{6} e^{4 x_{0}} + C_{6} + C_{8} e^{4 x_{0}} - C_{8} - C_{9} e^{4 x_{0}} - C_{9} + 2 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ is $0$<br>
# Replace $\operatorname{c_{1 1}}{\left(x_{0} \right)}$ with $$\frac{\left(- C_{5} e^{2 x_{0}} + C_{5} + C_{6} e^{2 x_{0}} + C_{6} + C_{8} e^{2 x_{0}} - C_{8} - C_{9} e^{2 x_{0}} - C_{9} + 2 \operatorname{c_{2 1}}{\left(x_{0} \right)} e^{2 x_{0}}\right) e^{- 2 x_{0}}}{2}$$
# Original tangent:$$\eta=x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)} + \operatorname{c_{2 0}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ is $1$<br>
# Replace $\operatorname{c_{2 0}}{\left(x_{0} \right)}$ with $$\frac{C_{4} e^{2 x_{0}}}{2} - \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} + \frac{C_{7}}{2}$$
# Original tangent:$$\eta=\frac{C_{4} e^{2 x_{0}}}{2} - \frac{C_{4}}{2} + \frac{C_{7} e^{2 x_{0}}}{2} + \frac{C_{7}}{2} + x_{1} \operatorname{c_{2 1}}{\left(x_{0} \right)} + x_{2} \operatorname{c_{2 2}}{\left(x_{0} \right)}$$
# Coefficient of $\operatorname{c_{2 2}}{\left(x_{0} \right)}$ is $x_2$<br>
# Replace $\operatorname{c_{2 2}}{\left(x_{0} \right)}$ with $$\frac{C_{5} e^{2 x_{0}}}{2} - \frac{C_{5}}{2} - \frac{C_{6} e^{2 x_{0}}}{2} + \frac{C_{6}}{2} + \frac{C_{8} e^{2 x_{0}}}{2} + \frac{C_{8}}{2} - \frac{C_{9} e^{2 x_{0}}}{2} - \frac{C_{9}}{2} + \operatorname{c_{2 1}}{\left(x_{0} \right)}$$

# %% [markdown]
# # Second attempt with expanding
